# %% [markdown]
# # ETL Processes
# Use this notebook to develop the ETL process for each of your tables before completing the `etl.py` file to load the whole datasets.

# %%
import os
import glob
import psycopg2
import pandas as pd
from sql_queries import *

# %%
conn = psycopg2.connect("host=127.0.0.1 dbname=sparkifydb user=student password=student")
cur = conn.cursor()

# %%
def get_files(filepath):
    all_files = []
    for root, dirs, files in os.walk(filepath):
        files = glob.glob(os.path.join(root,'*.json'))
        for f in files :
            all_files.append(os.path.abspath(f))
    
    return all_files

# %% [markdown]
# # Process `song_data`
# In this first part, you'll perform ETL on the first dataset, `song_data`, to create the `songs` and `artists` dimensional tables.
#
# Let's perform ETL on a single song file and load a single record into each table to start.
# - Use the `get_files` function provided above to get a list of all song JSON files in `data/song_data`
# - Select the first song in this list
# - Read the song file and view the data

# %%
song_files = get_files('data/song_data')

# %%
filepath = song_files[0]

# %%
df = pd.read_json(filepath,lines=True)
df.head()
# Out:
#             artist_id  artist_latitude  artist_location  artist_longitude  \
# 0  ARD7TVE1187B99BFB1              NaN  California - LA               NaN
#
#   artist_name   duration  num_songs             song_id             title  \
# 0      Casual  218.93179          1  SOMZWCG12A8C13C480  I Didn't Mean To
#
#    year
# 0     0

# %% [markdown]
# ## #1: `songs` Table
# #### Extract Data for Songs Table
# - Select columns for song ID, title, artist ID, year, and duration
# - Use `df.values` to select just the values from the dataframe
# - Index to select the first (only) record in the dataframe
# - Convert the array to a list and set it to `song_data`

# %%
song_data = df[['song_id','title','artist_id','year','duration']].values[0].tolist()
song_data
# Out:
# [['SOMZWCG12A8C13C480',
#   "I Didn't Mean To",
#   'ARD7TVE1187B99BFB1',
#   0,
#   218.93179]]

# %% [markdown]
# #### Insert Record into Song Table
# Implement the `song_table_insert` query in `sql_queries.py` and run the cell below to insert a record for this song into the `songs` table. Remember to run `create_tables.py` before running the cell below to ensure you've created/resetted the `songs` table in the sparkify database.

# %%
cur.execute(song_table_insert, song_data)
conn.commit()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-8-0c375ac7939b> in <module>()
# ----> 1 cur.execute(song_table_insert, song_data)
#       2 conn.commit()
#
# IndexError: list index out of range

# %% [markdown]
# Run `test.ipynb` to see if you've successfully added a record to this table.

# %% [markdown]
# ## #2: `artists` Table
# #### Extract Data for Artists Table
# - Select columns for artist ID, name, location, latitude, and longitude
# - Use `df.values` to select just the values from the dataframe
# - Index to select the first (only) record in the dataframe
# - Convert the array to a list and set it to `artist_data`

# %%
artist_data = df[['artist_id','artist_name','artist_location','artist_latitude','artist_longitude']].values[0].tolist()
artist_data
# Out:
# ['ARD7TVE1187B99BFB1', 'Casual', 'California - LA', nan, nan]

# %% [markdown]
# #### Insert Record into Artist Table
# Implement the `artist_table_insert` query in `sql_queries.py` and run the cell below to insert a record for this song's artist into the `artists` table. Remember to run `create_tables.py` before running the cell below to ensure you've created/resetted the `artists` table in the sparkify database.

# %%
cur.execute(artist_table_insert, artist_data)
conn.commit()

# %% [markdown]
# Run `test.ipynb` to see if you've successfully added a record to this table.

# %% [markdown]
# # Process `log_data`
# In this part, you'll perform ETL on the second dataset, `log_data`, to create the `time` and `users` dimensional tables, as well as the `songplays` fact table.
#
# Let's perform ETL on a single log file and load a single record into each table.
# - Use the `get_files` function provided above to get a list of all log JSON files in `data/log_data`
# - Select the first log file in this list
# - Read the log file and view the data

# %%
log_files = get_files('data/log_data')

# %%
filepath = log_files[0]

# %%
df = pd.read_json(filepath,lines=True)
df.head()
# Out:
#           artist       auth firstName gender  itemInSession lastName  \
# 0  Stephen Lynch  Logged In    Jayden      M              0     Bell
# 1        Manowar  Logged In     Jacob      M              0    Klein
# 2      Morcheeba  Logged In     Jacob      M              1    Klein
# 3       Maroon 5  Logged In     Jacob      M              2    Klein
# 4          Train  Logged In     Jacob      M              3    Klein
#
#       length level                             location method      page  \
# 0  182.85669  free      Dallas-Fort Worth-Arlington, TX    PUT  NextSong
# 1  247.56200  paid  Tampa-St. Petersburg-Clearwater, FL    PUT  NextSong
# 2  257.41016  paid  Tampa-St. Petersburg-Clearwater, FL    PUT  NextSong
# 3  231.23546  paid  Tampa-St. Petersburg-Clearwater, FL    PUT  NextSong
# 4  216.76363  paid  Tampa-St. Petersburg-Clearwater, FL    PUT  NextSong
#
#    registration  sessionId                                  song  status  \
# 0  1.540992e+12        829                     Jim Henson's Dead     200
# 1  1.540558e+12       1049                           Shell Shock     200
# 2  1.540558e+12       1049  Women Lose Weight (Feat: Slick Rick)     200
# 3  1.540558e+12       1049             Won't Go Home Without You     200
# 4  1.540558e+12       1049                      Hey_ Soul Sister     200
#
#               ts                                          userAgent userId
# 0  1543537327796  Mozilla/5.0 (compatible; MSIE 10.0; Windows NT...     91
# 1  1543540121796  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...     73
# 2  1543540368796  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...     73
# 3  1543540625796  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...     73
# 4  1543540856796  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...     73

# %% [markdown]
# ## #3: `time` Table
# #### Extract Data for Time Table
# - Filter records by `NextSong` action
# - Convert the `ts` timestamp column to datetime
#   - Hint: the current timestamp is in milliseconds
# - Extract the timestamp, hour, day, week of year, month, year, and weekday from the `ts` column and set `time_data` to a list containing these values in order
#   - Hint: use pandas' [`dt` attribute](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Series.dt.html) to access easily datetimelike properties.
# - Specify labels for these columns and set to `column_labels`
# - Create a dataframe, `time_df,` containing the time data for this file by combining `column_labels` and `time_data` into a dictionary and converting this into a dataframe

# %%
df = df.loc[df['page'] == 'NextSong']
df.head()
# Out:
#           artist       auth firstName gender  itemInSession lastName  \
# 0  Stephen Lynch  Logged In    Jayden      M              0     Bell
# 1        Manowar  Logged In     Jacob      M              0    Klein
# 2      Morcheeba  Logged In     Jacob      M              1    Klein
# 3       Maroon 5  Logged In     Jacob      M              2    Klein
# 4          Train  Logged In     Jacob      M              3    Klein
#
#       length level                             location method      page  \
# 0  182.85669  free      Dallas-Fort Worth-Arlington, TX    PUT  NextSong
# 1  247.56200  paid  Tampa-St. Petersburg-Clearwater, FL    PUT  NextSong
# 2  257.41016  paid  Tampa-St. Petersburg-Clearwater, FL    PUT  NextSong
# 3  231.23546  paid  Tampa-St. Petersburg-Clearwater, FL    PUT  NextSong
# 4  216.76363  paid  Tampa-St. Petersburg-Clearwater, FL    PUT  NextSong
#
#    registration  sessionId                                  song  status  \
# 0  1.540992e+12        829                     Jim Henson's Dead     200
# 1  1.540558e+12       1049                           Shell Shock     200
# 2  1.540558e+12       1049  Women Lose Weight (Feat: Slick Rick)     200
# 3  1.540558e+12       1049             Won't Go Home Without You     200
# 4  1.540558e+12       1049                      Hey_ Soul Sister     200
#
#               ts                                          userAgent userId
# 0  1543537327796  Mozilla/5.0 (compatible; MSIE 10.0; Windows NT...     91
# 1  1543540121796  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...     73
# 2  1543540368796  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...     73
# 3  1543540625796  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...     73
# 4  1543540856796  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...     73

# %%
t = pd.to_datetime(df['ts'],unit='ms')
t.head()
# Out:
# 0   2018-11-30 00:22:07.796
# 1   2018-11-30 01:08:41.796
# 2   2018-11-30 01:12:48.796
# 3   2018-11-30 01:17:05.796
# 4   2018-11-30 01:20:56.796
# Name: ts, dtype: datetime64[ns]

# %%
time_data = list(zip(t.dt.strftime('%Y-%m-%d %I:%M:%S'),t.dt.hour,t.dt.day,t.dt.week,t.dt.month,t.dt.year,t.dt.weekday))
column_labels = ['StartTime','Hour','Day','Week','Month','Year','Weekday']

# %%
time_df = pd.DataFrame(time_data,columns=column_labels)
time_df.head()
# Out:
#              StartTime  Hour  Day  Week  Month  Year  Weekday
# 0  2018-11-30 12:22:07     0   30    48     11  2018        4
# 1  2018-11-30 01:08:41     1   30    48     11  2018        4
# 2  2018-11-30 01:12:48     1   30    48     11  2018        4
# 3  2018-11-30 01:17:05     1   30    48     11  2018        4
# 4  2018-11-30 01:20:56     1   30    48     11  2018        4

# %%
for i, row in time_df.iterrows():
    print(list(row))
# Out:
# ['2018-11-30 12:22:07', 0, 30, 48, 11, 2018, 4]
# ['2018-11-30 01:08:41', 1, 30, 48, 11, 2018, 4]
# ['2018-11-30 01:12:48', 1, 30, 48, 11, 2018, 4]
# ['2018-11-30 01:17:05', 1, 30, 48, 11, 2018, 4]
# ['2018-11-30 01:20:56', 1, 30, 48, 11, 2018, 4]
# ['2018-11-30 01:24:32', 1, 30, 48, 11, 2018, 4]
# ['2018-11-30 01:28:19', 1, 30, 48, 11, 2018, 4]
# ['2018-11-30 01:32:00', 1, 30, 48, 11, 2018, 4]
# ['2018-11-30 01:38:17', 1, 30, 48, 11, 2018, 4]
# ['2018-11-30 01:39:53', 1, 30, 48, 11, 2018, 4]
# ['2018-11-30 01:44:10', 1, 30, 48, 11, 2018, 4]
# ['2018-11-30 01:48:36', 1, 30, 48, 11, 2018, 4]
# ['2018-11-30 01:50:28', 1, 30, 48, 11, 2018, 4]
# ['2018-11-30 01:55:35', 1, 30, 48, 11, 2018, 4]
# ['2018-11-30 02:01:08', 2, 30, 48, 11, 2018, 4]
# ['2018-11-30 02:05:24', 2, 30, 48, 11, 2018, 4]
# ['2018-11-30 02:10:21', 2, 30, 48, 11, 2018, 4]
# ['2018-11-30 02:15:54', 2, 30, 48, 11, 2018, 4]
# ['2018-11-30 02:19:19', 2, 30, 48, 11, 2018, 4]
# ['2018-11-30 03:06:30', 3, 30, 48, 11, 2018, 4]
# ['2018-11-30 03:10:30', 3, 30, 48, 11, 2018, 4]
# ['2018-11-30 03:13:03', 3, 30, 48, 11, 2018, 4]
# ['2018-11-30 03:15:41', 3, 30, 48, 11, 2018, 4]
# ['2018-11-30 03:21:09', 3, 30, 48, 11, 2018, 4]
# ['2018-11-30 03:29:23', 3, 30, 48, 11, 2018, 4]
# ['2018-11-30 03:32:46', 3, 30, 48, 11, 2018, 4]
# ['2018-11-30 03:37:24', 3, 30, 48, 11, 2018, 4]
# ['2018-11-30 03:39:31', 3, 30, 48, 11, 2018, 4]
# ['2018-11-30 03:44:28', 3, 30, 48, 11, 2018, 4]
# ['2018-11-30 03:49:50', 3, 30, 48, 11, 2018, 4]
# ['2018-11-30 03:55:42', 3, 30, 48, 11, 2018, 4]
# ['2018-11-30 03:58:21', 3, 30, 48, 11, 2018, 4]
# ['2018-11-30 04:00:57', 4, 30, 48, 11, 2018, 4]
# ['2018-11-30 04:04:13', 4, 30, 48, 11, 2018, 4]
# ['2018-11-30 04:06:01', 4, 30, 48, 11, 2018, 4]
# ['2018-11-30 04:09:20', 4, 30, 48, 11, 2018, 4]
# ['2018-11-30 04:12:58', 4, 30, 48, 11, 2018, 4]
# ['2018-11-30 04:13:07', 4, 30, 48, 11, 2018, 4]
# ['2018-11-30 04:17:10', 4, 30, 48, 11, 2018, 4]
# ['2018-11-30 04:20:32', 4, 30, 48, 11, 2018, 4]
# ['2018-11-30 04:21:20', 4, 30, 48, 11, 2018, 4]
# ['2018-11-30 04:23:31', 4, 30, 48, 11, 2018, 4]
# ['2018-11-30 04:24:50', 4, 30, 48, 11, 2018, 4]
# ['2018-11-30 04:26:49', 4, 30, 48, 11, 2018, 4]
# ['2018-11-30 04:27:14', 4, 30, 48, 11, 2018, 4]
# ['2018-11-30 04:31:08', 4, 30, 48, 11, 2018, 4]
# ['2018-11-30 04:32:02', 4, 30, 48, 11, 2018, 4]
# ['2018-11-30 04:36:30', 4, 30, 48, 11, 2018, 4]
# ['2018-11-30 04:42:05', 4, 30, 48, 11, 2018, 4]
# ['2018-11-30 04:46:03', 4, 30, 48, 11, 2018, 4]
# ['2018-11-30 04:51:49', 4, 30, 48, 11, 2018, 4]
# ['2018-11-30 04:56:11', 4, 30, 48, 11, 2018, 4]
# ['2018-11-30 04:57:03', 4, 30, 48, 11, 2018, 4]
# ['2018-11-30 05:03:06', 5, 30, 48, 11, 2018, 4]
# ['2018-11-30 05:06:32', 5, 30, 48, 11, 2018, 4]
# ['2018-11-30 05:11:09', 5, 30, 48, 11, 2018, 4]
# ['2018-11-30 05:12:20', 5, 30, 48, 11, 2018, 4]
# ['2018-11-30 05:15:12', 5, 30, 48, 11, 2018, 4]
# ['2018-11-30 05:16:54', 5, 30, 48, 11, 2018, 4]
# ['2018-11-30 05:19:35', 5, 30, 48, 11, 2018, 4]
# ['2018-11-30 05:20:54', 5, 30, 48, 11, 2018, 4]
# ['2018-11-30 05:23:34', 5, 30, 48, 11, 2018, 4]
# ['2018-11-30 05:24:45', 5, 30, 48, 11, 2018, 4]
# ['2018-11-30 05:28:28', 5, 30, 48, 11, 2018, 4]
# ['2018-11-30 05:29:04', 5, 30, 48, 11, 2018, 4]
# ['2018-11-30 05:31:25', 5, 30, 48, 11, 2018, 4]
# ['2018-11-30 05:31:44', 5, 30, 48, 11, 2018, 4]
# ['2018-11-30 05:32:47', 5, 30, 48, 11, 2018, 4]
# ['2018-11-30 05:36:03', 5, 30, 48, 11, 2018, 4]
# ['2018-11-30 05:36:45', 5, 30, 48, 11, 2018, 4]
# ['2018-11-30 05:39:39', 5, 30, 48, 11, 2018, 4]
# ['2018-11-30 05:40:31', 5, 30, 48, 11, 2018, 4]
# ['2018-11-30 05:43:04', 5, 30, 48, 11, 2018, 4]
# ['2018-11-30 05:43:56', 5, 30, 48, 11, 2018, 4]
# ['2018-11-30 05:46:01', 5, 30, 48, 11, 2018, 4]
# ['2018-11-30 05:48:56', 5, 30, 48, 11, 2018, 4]
# ['2018-11-30 05:50:07', 5, 30, 48, 11, 2018, 4]
# ['2018-11-30 05:54:19', 5, 30, 48, 11, 2018, 4]
# ['2018-11-30 05:57:11', 5, 30, 48, 11, 2018, 4]
# ['2018-11-30 05:58:01', 5, 30, 48, 11, 2018, 4]
# ['2018-11-30 06:01:40', 6, 30, 48, 11, 2018, 4]
# ['2018-11-30 06:04:50', 6, 30, 48, 11, 2018, 4]
# ['2018-11-30 06:04:55', 6, 30, 48, 11, 2018, 4]
# ['2018-11-30 06:07:57', 6, 30, 48, 11, 2018, 4]
# ['2018-11-30 06:10:18', 6, 30, 48, 11, 2018, 4]
# ['2018-11-30 06:12:54', 6, 30, 48, 11, 2018, 4]
# ['2018-11-30 06:13:23', 6, 30, 48, 11, 2018, 4]
# ['2018-11-30 06:14:02', 6, 30, 48, 11, 2018, 4]
# ['2018-11-30 06:16:35', 6, 30, 48, 11, 2018, 4]
# ['2018-11-30 06:18:28', 6, 30, 48, 11, 2018, 4]
# ['2018-11-30 06:21:31', 6, 30, 48, 11, 2018, 4]
# ['2018-11-30 06:26:25', 6, 30, 48, 11, 2018, 4]
# ['2018-11-30 06:30:35', 6, 30, 48, 11, 2018, 4]
# ['2018-11-30 06:33:56', 6, 30, 48, 11, 2018, 4]
# ['2018-11-30 06:37:14', 6, 30, 48, 11, 2018, 4]
# ['2018-11-30 06:40:47', 6, 30, 48, 11, 2018, 4]
# ['2018-11-30 06:44:27', 6, 30, 48, 11, 2018, 4]
# ['2018-11-30 06:48:28', 6, 30, 48, 11, 2018, 4]
# ['2018-11-30 06:52:31', 6, 30, 48, 11, 2018, 4]
# ['2018-11-30 06:54:42', 6, 30, 48, 11, 2018, 4]
# ['2018-11-30 06:58:38', 6, 30, 48, 11, 2018, 4]
# ['2018-11-30 07:02:23', 7, 30, 48, 11, 2018, 4]
# ['2018-11-30 07:08:35', 7, 30, 48, 11, 2018, 4]
# ['2018-11-30 07:15:24', 7, 30, 48, 11, 2018, 4]
# ['2018-11-30 07:18:31', 7, 30, 48, 11, 2018, 4]
# ['2018-11-30 07:22:12', 7, 30, 48, 11, 2018, 4]
# ['2018-11-30 07:24:45', 7, 30, 48, 11, 2018, 4]
# ['2018-11-30 07:28:29', 7, 30, 48, 11, 2018, 4]
# ['2018-11-30 07:29:09', 7, 30, 48, 11, 2018, 4]
# ['2018-11-30 07:31:39', 7, 30, 48, 11, 2018, 4]
# ['2018-11-30 07:36:23', 7, 30, 48, 11, 2018, 4]
# ['2018-11-30 07:38:51', 7, 30, 48, 11, 2018, 4]
# ['2018-11-30 07:42:37', 7, 30, 48, 11, 2018, 4]
# ['2018-11-30 07:47:05', 7, 30, 48, 11, 2018, 4]
# ['2018-11-30 07:49:54', 7, 30, 48, 11, 2018, 4]
# ['2018-11-30 08:16:11', 8, 30, 48, 11, 2018, 4]
# ['2018-11-30 08:20:12', 8, 30, 48, 11, 2018, 4]
# ['2018-11-30 08:21:57', 8, 30, 48, 11, 2018, 4]
# ['2018-11-30 08:26:07', 8, 30, 48, 11, 2018, 4]
# ['2018-11-30 08:29:58', 8, 30, 48, 11, 2018, 4]
# ['2018-11-30 08:32:43', 8, 30, 48, 11, 2018, 4]
# ['2018-11-30 08:38:38', 8, 30, 48, 11, 2018, 4]
# ['2018-11-30 08:46:21', 8, 30, 48, 11, 2018, 4]
# ['2018-11-30 10:12:54', 10, 30, 48, 11, 2018, 4]
# ['2018-11-30 10:18:07', 10, 30, 48, 11, 2018, 4]
# ['2018-11-30 10:22:53', 10, 30, 48, 11, 2018, 4]
# ['2018-11-30 10:27:08', 10, 30, 48, 11, 2018, 4]
# ['2018-11-30 10:30:53', 10, 30, 48, 11, 2018, 4]
# ['2018-11-30 10:35:18', 10, 30, 48, 11, 2018, 4]
# ['2018-11-30 10:38:54', 10, 30, 48, 11, 2018, 4]
# ['2018-11-30 10:42:09', 10, 30, 48, 11, 2018, 4]
# ['2018-11-30 10:46:06', 10, 30, 48, 11, 2018, 4]
# ['2018-11-30 10:49:40', 10, 30, 48, 11, 2018, 4]
# ['2018-11-30 10:54:05', 10, 30, 48, 11, 2018, 4]
# ['2018-11-30 10:56:25', 10, 30, 48, 11, 2018, 4]
# ['2018-11-30 10:59:23', 10, 30, 48, 11, 2018, 4]
# ['2018-11-30 11:00:01', 11, 30, 48, 11, 2018, 4]
# ['2018-11-30 11:06:18', 11, 30, 48, 11, 2018, 4]
# ['2018-11-30 11:09:49', 11, 30, 48, 11, 2018, 4]
# ['2018-11-30 11:10:18', 11, 30, 48, 11, 2018, 4]
# ['2018-11-30 11:13:07', 11, 30, 48, 11, 2018, 4]
# ['2018-11-30 11:16:10', 11, 30, 48, 11, 2018, 4]
# ['2018-11-30 11:20:03', 11, 30, 48, 11, 2018, 4]
# ['2018-11-30 11:23:44', 11, 30, 48, 11, 2018, 4]
# ['2018-11-30 11:28:16', 11, 30, 48, 11, 2018, 4]
# ['2018-11-30 11:32:04', 11, 30, 48, 11, 2018, 4]
# ['2018-11-30 11:37:23', 11, 30, 48, 11, 2018, 4]
# ['2018-11-30 11:41:03', 11, 30, 48, 11, 2018, 4]
# ['2018-11-30 11:46:23', 11, 30, 48, 11, 2018, 4]
# ['2018-11-30 11:49:42', 11, 30, 48, 11, 2018, 4]
# ['2018-11-30 12:10:57', 12, 30, 48, 11, 2018, 4]
# ['2018-11-30 12:31:18', 12, 30, 48, 11, 2018, 4]
# ['2018-11-30 12:34:47', 12, 30, 48, 11, 2018, 4]
# ['2018-11-30 12:39:36', 12, 30, 48, 11, 2018, 4]
# ['2018-11-30 12:47:53', 12, 30, 48, 11, 2018, 4]
# ['2018-11-30 12:52:50', 12, 30, 48, 11, 2018, 4]
# ['2018-11-30 12:57:05', 12, 30, 48, 11, 2018, 4]
# ['2018-11-30 12:57:53', 12, 30, 48, 11, 2018, 4]
# ['2018-11-30 01:01:42', 13, 30, 48, 11, 2018, 4]
# ['2018-11-30 01:05:54', 13, 30, 48, 11, 2018, 4]
# ['2018-11-30 01:10:16', 13, 30, 48, 11, 2018, 4]
# ['2018-11-30 01:13:45', 13, 30, 48, 11, 2018, 4]
# ['2018-11-30 01:17:25', 13, 30, 48, 11, 2018, 4]
# ['2018-11-30 01:20:30', 13, 30, 48, 11, 2018, 4]
# ['2018-11-30 01:20:44', 13, 30, 48, 11, 2018, 4]
# ['2018-11-30 01:27:49', 13, 30, 48, 11, 2018, 4]
# ['2018-11-30 01:31:28', 13, 30, 48, 11, 2018, 4]
# ['2018-11-30 01:34:49', 13, 30, 48, 11, 2018, 4]
# ['2018-11-30 01:38:42', 13, 30, 48, 11, 2018, 4]
# ['2018-11-30 01:41:51', 13, 30, 48, 11, 2018, 4]
# ['2018-11-30 01:43:40', 13, 30, 48, 11, 2018, 4]
# ['2018-11-30 01:45:20', 13, 30, 48, 11, 2018, 4]
# ['2018-11-30 01:48:07', 13, 30, 48, 11, 2018, 4]
# ['2018-11-30 01:48:55', 13, 30, 48, 11, 2018, 4]
# ['2018-11-30 01:52:37', 13, 30, 48, 11, 2018, 4]
# ['2018-11-30 01:52:55', 13, 30, 48, 11, 2018, 4]
# ['2018-11-30 01:56:36', 13, 30, 48, 11, 2018, 4]
# ['2018-11-30 01:57:21', 13, 30, 48, 11, 2018, 4]
# ['2018-11-30 01:57:24', 13, 30, 48, 11, 2018, 4]
# ['2018-11-30 01:59:31', 13, 30, 48, 11, 2018, 4]
# ['2018-11-30 02:00:38', 14, 30, 48, 11, 2018, 4]
# ['2018-11-30 02:01:42', 14, 30, 48, 11, 2018, 4]
# ['2018-11-30 02:01:43', 14, 30, 48, 11, 2018, 4]
# ['2018-11-30 02:03:21', 14, 30, 48, 11, 2018, 4]
# ['2018-11-30 02:04:47', 14, 30, 48, 11, 2018, 4]
# ['2018-11-30 02:06:43', 14, 30, 48, 11, 2018, 4]
# ['2018-11-30 02:07:56', 14, 30, 48, 11, 2018, 4]
# ['2018-11-30 02:10:01', 14, 30, 48, 11, 2018, 4]
# ['2018-11-30 02:11:25', 14, 30, 48, 11, 2018, 4]
# ['2018-11-30 02:12:16', 14, 30, 48, 11, 2018, 4]
# ['2018-11-30 02:15:25', 14, 30, 48, 11, 2018, 4]
# ['2018-11-30 02:16:36', 14, 30, 48, 11, 2018, 4]
# ['2018-11-30 02:19:48', 14, 30, 48, 11, 2018, 4]
# ['2018-11-30 02:21:45', 14, 30, 48, 11, 2018, 4]
# ['2018-11-30 02:24:02', 14, 30, 48, 11, 2018, 4]
# ['2018-11-30 02:27:42', 14, 30, 48, 11, 2018, 4]
# ['2018-11-30 02:28:26', 14, 30, 48, 11, 2018, 4]
# ['2018-11-30 02:31:15', 14, 30, 48, 11, 2018, 4]
# ['2018-11-30 02:33:39', 14, 30, 48, 11, 2018, 4]
# ['2018-11-30 02:33:53', 14, 30, 48, 11, 2018, 4]
# ['2018-11-30 02:36:07', 14, 30, 48, 11, 2018, 4]
# ['2018-11-30 02:37:56', 14, 30, 48, 11, 2018, 4]
# ['2018-11-30 02:38:37', 14, 30, 48, 11, 2018, 4]
# ['2018-11-30 02:41:06', 14, 30, 48, 11, 2018, 4]
# ['2018-11-30 02:42:01', 14, 30, 48, 11, 2018, 4]
# ['2018-11-30 02:42:38', 14, 30, 48, 11, 2018, 4]
# ['2018-11-30 02:42:45', 14, 30, 48, 11, 2018, 4]
# ['2018-11-30 02:43:50', 14, 30, 48, 11, 2018, 4]
# ['2018-11-30 02:45:13', 14, 30, 48, 11, 2018, 4]
# ['2018-11-30 02:46:43', 14, 30, 48, 11, 2018, 4]
# ['2018-11-30 02:47:35', 14, 30, 48, 11, 2018, 4]
# ['2018-11-30 02:49:37', 14, 30, 48, 11, 2018, 4]
# ['2018-11-30 02:51:37', 14, 30, 48, 11, 2018, 4]
# ['2018-11-30 02:52:04', 14, 30, 48, 11, 2018, 4]
# ['2018-11-30 02:53:33', 14, 30, 48, 11, 2018, 4]
# ['2018-11-30 02:55:25', 14, 30, 48, 11, 2018, 4]
# ['2018-11-30 02:57:52', 14, 30, 48, 11, 2018, 4]
# ['2018-11-30 02:59:31', 14, 30, 48, 11, 2018, 4]
# ['2018-11-30 02:59:32', 14, 30, 48, 11, 2018, 4]
# ['2018-11-30 03:01:06', 15, 30, 48, 11, 2018, 4]
# ['2018-11-30 03:02:42', 15, 30, 48, 11, 2018, 4]
# ['2018-11-30 03:05:47', 15, 30, 48, 11, 2018, 4]
# ['2018-11-30 03:05:56', 15, 30, 48, 11, 2018, 4]
# ['2018-11-30 03:06:38', 15, 30, 48, 11, 2018, 4]
# ['2018-11-30 03:09:01', 15, 30, 48, 11, 2018, 4]
# ['2018-11-30 03:10:07', 15, 30, 48, 11, 2018, 4]
# ['2018-11-30 03:11:47', 15, 30, 48, 11, 2018, 4]
# ['2018-11-30 03:12:54', 15, 30, 48, 11, 2018, 4]
# ['2018-11-30 03:13:03', 15, 30, 48, 11, 2018, 4]
# ['2018-11-30 03:14:35', 15, 30, 48, 11, 2018, 4]
# ['2018-11-30 03:15:05', 15, 30, 48, 11, 2018, 4]
# ['2018-11-30 03:16:02', 15, 30, 48, 11, 2018, 4]
# ['2018-11-30 03:17:07', 15, 30, 48, 11, 2018, 4]
# ['2018-11-30 03:18:58', 15, 30, 48, 11, 2018, 4]
# ['2018-11-30 03:21:29', 15, 30, 48, 11, 2018, 4]
# ['2018-11-30 03:22:09', 15, 30, 48, 11, 2018, 4]
# ['2018-11-30 03:22:54', 15, 30, 48, 11, 2018, 4]
# ['2018-11-30 03:24:45', 15, 30, 48, 11, 2018, 4]
# ['2018-11-30 03:25:59', 15, 30, 48, 11, 2018, 4]
# ['2018-11-30 03:27:25', 15, 30, 48, 11, 2018, 4]
# ['2018-11-30 03:28:30', 15, 30, 48, 11, 2018, 4]
# ['2018-11-30 03:32:00', 15, 30, 48, 11, 2018, 4]
# ['2018-11-30 03:33:06', 15, 30, 48, 11, 2018, 4]
# ['2018-11-30 03:37:07', 15, 30, 48, 11, 2018, 4]
# ['2018-11-30 03:42:22', 15, 30, 48, 11, 2018, 4]
# ['2018-11-30 03:46:15', 15, 30, 48, 11, 2018, 4]
# ['2018-11-30 03:50:08', 15, 30, 48, 11, 2018, 4]
# ['2018-11-30 03:51:02', 15, 30, 48, 11, 2018, 4]
# ['2018-11-30 03:53:37', 15, 30, 48, 11, 2018, 4]
# ['2018-11-30 03:54:23', 15, 30, 48, 11, 2018, 4]
# ['2018-11-30 03:57:42', 15, 30, 48, 11, 2018, 4]
# ['2018-11-30 03:58:51', 15, 30, 48, 11, 2018, 4]
# ['2018-11-30 04:00:31', 16, 30, 48, 11, 2018, 4]
# ['2018-11-30 04:03:06', 16, 30, 48, 11, 2018, 4]
# ['2018-11-30 04:06:15', 16, 30, 48, 11, 2018, 4]
# ['2018-11-30 04:07:52', 16, 30, 48, 11, 2018, 4]
# ['2018-11-30 04:09:16', 16, 30, 48, 11, 2018, 4]
# ['2018-11-30 04:12:03', 16, 30, 48, 11, 2018, 4]
# ['2018-11-30 04:13:08', 16, 30, 48, 11, 2018, 4]
# ['2018-11-30 04:15:19', 16, 30, 48, 11, 2018, 4]
# ['2018-11-30 04:17:45', 16, 30, 48, 11, 2018, 4]
# ['2018-11-30 04:18:18', 16, 30, 48, 11, 2018, 4]
# ['2018-11-30 04:20:04', 16, 30, 48, 11, 2018, 4]
# ['2018-11-30 04:21:23', 16, 30, 48, 11, 2018, 4]
# ['2018-11-30 04:21:33', 16, 30, 48, 11, 2018, 4]
# ['2018-11-30 04:25:17', 16, 30, 48, 11, 2018, 4]
# ['2018-11-30 04:27:09', 16, 30, 48, 11, 2018, 4]
# ['2018-11-30 04:31:25', 16, 30, 48, 11, 2018, 4]
# ['2018-11-30 04:34:12', 16, 30, 48, 11, 2018, 4]
# ['2018-11-30 04:35:57', 16, 30, 48, 11, 2018, 4]
# ['2018-11-30 04:38:10', 16, 30, 48, 11, 2018, 4]
# ['2018-11-30 04:39:12', 16, 30, 48, 11, 2018, 4]
# ['2018-11-30 04:41:23', 16, 30, 48, 11, 2018, 4]
# ['2018-11-30 04:43:28', 16, 30, 48, 11, 2018, 4]
# ['2018-11-30 04:45:28', 16, 30, 48, 11, 2018, 4]
# ['2018-11-30 04:49:06', 16, 30, 48, 11, 2018, 4]
# ['2018-11-30 04:51:42', 16, 30, 48, 11, 2018, 4]
# ['2018-11-30 04:55:41', 16, 30, 48, 11, 2018, 4]
# ['2018-11-30 04:59:06', 16, 30, 48, 11, 2018, 4]
# ['2018-11-30 05:03:03', 17, 30, 48, 11, 2018, 4]
# ['2018-11-30 05:07:22', 17, 30, 48, 11, 2018, 4]
# ['2018-11-30 05:11:16', 17, 30, 48, 11, 2018, 4]
# ['2018-11-30 05:16:14', 17, 30, 48, 11, 2018, 4]
# ['2018-11-30 05:19:28', 17, 30, 48, 11, 2018, 4]
# ['2018-11-30 05:19:58', 17, 30, 48, 11, 2018, 4]
# ['2018-11-30 05:22:01', 17, 30, 48, 11, 2018, 4]
# ['2018-11-30 05:24:07', 17, 30, 48, 11, 2018, 4]
# ['2018-11-30 05:25:36', 17, 30, 48, 11, 2018, 4]
# ['2018-11-30 05:28:37', 17, 30, 48, 11, 2018, 4]
# ['2018-11-30 05:30:27', 17, 30, 48, 11, 2018, 4]
# ['2018-11-30 05:31:24', 17, 30, 48, 11, 2018, 4]
# ['2018-11-30 05:34:27', 17, 30, 48, 11, 2018, 4]
# ['2018-11-30 05:35:07', 17, 30, 48, 11, 2018, 4]
# ['2018-11-30 05:39:08', 17, 30, 48, 11, 2018, 4]
# ['2018-11-30 05:39:17', 17, 30, 48, 11, 2018, 4]
# ['2018-11-30 05:42:58', 17, 30, 48, 11, 2018, 4]
# ['2018-11-30 05:44:00', 17, 30, 48, 11, 2018, 4]
# ['2018-11-30 05:45:41', 17, 30, 48, 11, 2018, 4]
# ['2018-11-30 05:47:13', 17, 30, 48, 11, 2018, 4]
# ['2018-11-30 05:48:55', 17, 30, 48, 11, 2018, 4]
# ['2018-11-30 05:49:45', 17, 30, 48, 11, 2018, 4]
# ['2018-11-30 05:53:44', 17, 30, 48, 11, 2018, 4]
# ['2018-11-30 05:54:43', 17, 30, 48, 11, 2018, 4]
# ['2018-11-30 05:57:24', 17, 30, 48, 11, 2018, 4]
# ['2018-11-30 05:58:43', 17, 30, 48, 11, 2018, 4]
# ['2018-11-30 06:03:19', 18, 30, 48, 11, 2018, 4]
# ['2018-11-30 06:04:23', 18, 30, 48, 11, 2018, 4]
# ['2018-11-30 06:08:07', 18, 30, 48, 11, 2018, 4]
# ['2018-11-30 06:10:01', 18, 30, 48, 11, 2018, 4]
# ['2018-11-30 06:13:36', 18, 30, 48, 11, 2018, 4]
# ['2018-11-30 06:14:56', 18, 30, 48, 11, 2018, 4]
# ['2018-11-30 06:16:20', 18, 30, 48, 11, 2018, 4]
# ['2018-11-30 06:19:03', 18, 30, 48, 11, 2018, 4]
# ['2018-11-30 06:19:33', 18, 30, 48, 11, 2018, 4]
# ['2018-11-30 06:21:19', 18, 30, 48, 11, 2018, 4]
# ['2018-11-30 06:21:46', 18, 30, 48, 11, 2018, 4]
# ['2018-11-30 06:24:05', 18, 30, 48, 11, 2018, 4]
# ['2018-11-30 06:26:12', 18, 30, 48, 11, 2018, 4]
# ['2018-11-30 06:28:08', 18, 30, 48, 11, 2018, 4]
# ['2018-11-30 06:29:02', 18, 30, 48, 11, 2018, 4]
# ['2018-11-30 06:31:34', 18, 30, 48, 11, 2018, 4]
# ['2018-11-30 06:32:46', 18, 30, 48, 11, 2018, 4]
# ['2018-11-30 06:35:19', 18, 30, 48, 11, 2018, 4]
# ['2018-11-30 06:36:25', 18, 30, 48, 11, 2018, 4]
# ['2018-11-30 06:39:22', 18, 30, 48, 11, 2018, 4]
# ['2018-11-30 06:40:05', 18, 30, 48, 11, 2018, 4]
# ['2018-11-30 06:44:36', 18, 30, 48, 11, 2018, 4]
# ['2018-11-30 06:47:58', 18, 30, 48, 11, 2018, 4]
# ['2018-11-30 06:51:24', 18, 30, 48, 11, 2018, 4]
# ['2018-11-30 07:54:24', 19, 30, 48, 11, 2018, 4]

# %% [markdown]
# #### Insert Records into Time Table
# Implement the `time_table_insert` query in `sql_queries.py` and run the cell below to insert records for the timestamps in this log file into the `time` table. Remember to run `create_tables.py` before running the cell below to ensure you've created/resetted the `time` table in the sparkify database.

# %%
for i, row in time_df.iterrows():
    cur.execute(time_table_insert, list(row))
    conn.commit()

# %% [markdown]
# Run `test.ipynb` to see if you've successfully added records to this table.

# %% [markdown]
# ## #4: `users` Table
# #### Extract Data for Users Table
# - Select columns for user ID, first name, last name, gender and level and set to `user_df`

# %%
user_df = df[['userId','firstName','lastName','gender','level']]

# %% [markdown]
# #### Insert Records into Users Table
# Implement the `user_table_insert` query in `sql_queries.py` and run the cell below to insert records for the users in this log file into the `users` table. Remember to run `create_tables.py` before running the cell below to ensure you've created/resetted the `users` table in the sparkify database.

# %%
user_df.head()
# Out:
#   userId firstName lastName gender level
# 0     91    Jayden     Bell      M  free
# 1     73     Jacob    Klein      M  paid
# 2     73     Jacob    Klein      M  paid
# 3     73     Jacob    Klein      M  paid
# 4     73     Jacob    Klein      M  paid

# %%
for i, row in user_df.iterrows():
    cur.execute(user_table_insert, row)
    conn.commit()

# %% [markdown]
# Run `test.ipynb` to see if you've successfully added records to this table.

# %% [markdown]
# ## #5: `songplays` Table
# #### Extract Data and Songplays Table
# This one is a little more complicated since information from the songs table, artists table, and original log file are all needed for the `songplays` table. Since the log file does not specify an ID for either the song or the artist, you'll need to get the song ID and artist ID by querying the songs and artists tables to find matches based on song title, artist name, and song duration time.
# - Implement the `song_select` query in `sql_queries.py` to find the song ID and artist ID based on the title, artist name, and duration of a song.
# - Select the timestamp, user ID, level, song ID, artist ID, session ID, location, and user agent and set to `songplay_data`
#
# #### Insert Records into Songplays Table
# -  the `songplay_table_insert` queImplementry and run the cell below to insert records for the songplay actions in this log file into the `songplays` table. Remember to run `create_tables.py` before running the cell below to ensure you've created/resetted the `songplays` table in the sparkify database.

# %%
for index, row in df.iterrows():

    # get songid and artistid from song and artist tables
    cur.execute(song_select, (row.song, row.artist, row.length))
    results = cur.fetchone()
    
    if results:
        songid, artistid = results
    else:
        songid, artistid = None, None

    # insert songplay record
    songplay_data = (row.ts,int(row.userId),row.level,songid,artistid,row.sessionId, row.location, row.userAgent)
    print(songplay_data)
    cur.execute(songplay_table_insert, songplay_data)
    conn.commit()
# Out:
# (1543537327796, 91, 'free', None, None, 829, 'Dallas-Fort Worth-Arlington, TX', 'Mozilla/5.0 (compatible; MSIE 10.0; Windows NT 6.2; WOW64; Trident/6.0)')
# (1543540121796, 73, 'paid', None, None, 1049, 'Tampa-St. Petersburg-Clearwater, FL', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.78.2 (KHTML, like Gecko) Version/7.0.6 Safari/537.78.2"')
# (1543540368796, 73, 'paid', None, None, 1049, 'Tampa-St. Petersburg-Clearwater, FL', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.78.2 (KHTML, like Gecko) Version/7.0.6 Safari/537.78.2"')
# (1543540625796, 73, 'paid', None, None, 1049, 'Tampa-St. Petersburg-Clearwater, FL', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.78.2 (KHTML, like Gecko) Version/7.0.6 Safari/537.78.2"')
# (1543540856796, 73, 'paid', None, None, 1049, 'Tampa-St. Petersburg-Clearwater, FL', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.78.2 (KHTML, like Gecko) Version/7.0.6 Safari/537.78.2"')
# (1543541072796, 73, 'paid', None, None, 1049, 'Tampa-St. Petersburg-Clearwater, FL', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.78.2 (KHTML, like Gecko) Version/7.0.6 Safari/537.78.2"')
# (1543541299796, 73, 'paid', None, None, 1049, 'Tampa-St. Petersburg-Clearwater, FL', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.78.2 (KHTML, like Gecko) Version/7.0.6 Safari/537.78.2"')
# (1543541520796, 73, 'paid', None, None, 1049, 'Tampa-St. Petersburg-Clearwater, FL', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.78.2 (KHTML, like Gecko) Version/7.0.6 Safari/537.78.2"')
# (1543541897796, 73, 'paid', None, None, 1049, 'Tampa-St. Petersburg-Clearwater, FL', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.78.2 (KHTML, like Gecko) Version/7.0.6 Safari/537.78.2"')
# (1543541993796, 73, 'paid', None, None, 1049, 'Tampa-St. Petersburg-Clearwater, FL', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.78.2 (KHTML, like Gecko) Version/7.0.6 Safari/537.78.2"')
# (1543542250796, 73, 'paid', None, None, 1049, 'Tampa-St. Petersburg-Clearwater, FL', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.78.2 (KHTML, like Gecko) Version/7.0.6 Safari/537.78.2"')
# (1543542516796, 73, 'paid', None, None, 1049, 'Tampa-St. Petersburg-Clearwater, FL', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.78.2 (KHTML, like Gecko) Version/7.0.6 Safari/537.78.2"')
# (1543542628796, 73, 'paid', None, None, 1049, 'Tampa-St. Petersburg-Clearwater, FL', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.78.2 (KHTML, like Gecko) Version/7.0.6 Safari/537.78.2"')
# (1543542935796, 73, 'paid', None, None, 1049, 'Tampa-St. Petersburg-Clearwater, FL', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.78.2 (KHTML, like Gecko) Version/7.0.6 Safari/537.78.2"')
# (1543543268796, 73, 'paid', None, None, 1049, 'Tampa-St. Petersburg-Clearwater, FL', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.78.2 (KHTML, like Gecko) Version/7.0.6 Safari/537.78.2"')
# (1543543524796, 73, 'paid', None, None, 1049, 'Tampa-St. Petersburg-Clearwater, FL', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.78.2 (KHTML, like Gecko) Version/7.0.6 Safari/537.78.2"')
# (1543543821796, 73, 'paid', None, None, 1049, 'Tampa-St. Petersburg-Clearwater, FL', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.78.2 (KHTML, like Gecko) Version/7.0.6 Safari/537.78.2"')
# (1543544154796, 73, 'paid', None, None, 1049, 'Tampa-St. Petersburg-Clearwater, FL', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.78.2 (KHTML, like Gecko) Version/7.0.6 Safari/537.78.2"')
# (1543544359796, 73, 'paid', None, None, 1049, 'Tampa-St. Petersburg-Clearwater, FL', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.78.2 (KHTML, like Gecko) Version/7.0.6 Safari/537.78.2"')
# (1543547190796, 86, 'free', None, None, 986, 'La Crosse-Onalaska, WI-MN', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/37.0.2062.94 Safari/537.36"')
# (1543547430796, 86, 'free', None, None, 986, 'La Crosse-Onalaska, WI-MN', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/37.0.2062.94 Safari/537.36"')
# (1543547583796, 86, 'free', None, None, 986, 'La Crosse-Onalaska, WI-MN', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/37.0.2062.94 Safari/537.36"')
# (1543547741796, 86, 'free', None, None, 986, 'La Crosse-Onalaska, WI-MN', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/37.0.2062.94 Safari/537.36"')
# (1543548069796, 86, 'free', None, None, 986, 'La Crosse-Onalaska, WI-MN', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/37.0.2062.94 Safari/537.36"')
# (1543548563796, 24, 'paid', None, None, 1051, 'Lake Havasu City-Kingman, AZ', '"Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.125 Safari/537.36"')
# (1543548766796, 24, 'paid', None, None, 1051, 'Lake Havasu City-Kingman, AZ', '"Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.125 Safari/537.36"')
# (1543549044796, 24, 'paid', None, None, 1051, 'Lake Havasu City-Kingman, AZ', '"Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.125 Safari/537.36"')
# (1543549171796, 24, 'paid', None, None, 1051, 'Lake Havasu City-Kingman, AZ', '"Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.125 Safari/537.36"')
# (1543549468796, 24, 'paid', None, None, 1051, 'Lake Havasu City-Kingman, AZ', '"Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.125 Safari/537.36"')
# (1543549790796, 24, 'paid', None, None, 1051, 'Lake Havasu City-Kingman, AZ', '"Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.125 Safari/537.36"')
# (1543550142796, 24, 'paid', None, None, 1051, 'Lake Havasu City-Kingman, AZ', '"Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.125 Safari/537.36"')
# (1543550301796, 26, 'free', None, None, 1068, 'San Jose-Sunnyvale-Santa Clara, CA', '"Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Ubuntu Chromium/36.0.1985.125 Chrome/36.0.1985.125 Safari/537.36"')
# (1543550457796, 24, 'paid', None, None, 1051, 'Lake Havasu City-Kingman, AZ', '"Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.125 Safari/537.36"')
# (1543550653796, 26, 'free', None, None, 1068, 'San Jose-Sunnyvale-Santa Clara, CA', '"Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Ubuntu Chromium/36.0.1985.125 Chrome/36.0.1985.125 Safari/537.36"')
# (1543550761796, 24, 'paid', None, None, 1051, 'Lake Havasu City-Kingman, AZ', '"Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.125 Safari/537.36"')
# (1543550960796, 26, 'free', None, None, 1068, 'San Jose-Sunnyvale-Santa Clara, CA', '"Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Ubuntu Chromium/36.0.1985.125 Chrome/36.0.1985.125 Safari/537.36"')
# (1543551178796, 24, 'paid', None, None, 1051, 'Lake Havasu City-Kingman, AZ', '"Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.125 Safari/537.36"')
# (1543551187796, 26, 'free', None, None, 1068, 'San Jose-Sunnyvale-Santa Clara, CA', '"Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Ubuntu Chromium/36.0.1985.125 Chrome/36.0.1985.125 Safari/537.36"')
# (1543551430796, 24, 'paid', None, None, 1051, 'Lake Havasu City-Kingman, AZ', '"Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.125 Safari/537.36"')
# (1543551632796, 24, 'paid', None, None, 1051, 'Lake Havasu City-Kingman, AZ', '"Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.125 Safari/537.36"')
# (1543551680796, 26, 'free', None, None, 1068, 'San Jose-Sunnyvale-Santa Clara, CA', '"Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Ubuntu Chromium/36.0.1985.125 Chrome/36.0.1985.125 Safari/537.36"')
# (1543551811796, 24, 'paid', None, None, 1051, 'Lake Havasu City-Kingman, AZ', '"Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.125 Safari/537.36"')
# (1543551890796, 26, 'free', None, None, 1068, 'San Jose-Sunnyvale-Santa Clara, CA', '"Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Ubuntu Chromium/36.0.1985.125 Chrome/36.0.1985.125 Safari/537.36"')
# (1543552009796, 24, 'paid', None, None, 1051, 'Lake Havasu City-Kingman, AZ', '"Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.125 Safari/537.36"')
# (1543552034796, 26, 'free', None, None, 1068, 'San Jose-Sunnyvale-Santa Clara, CA', '"Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Ubuntu Chromium/36.0.1985.125 Chrome/36.0.1985.125 Safari/537.36"')
# (1543552268796, 24, 'paid', None, None, 1051, 'Lake Havasu City-Kingman, AZ', '"Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.125 Safari/537.36"')
# (1543552322796, 26, 'free', None, None, 1068, 'San Jose-Sunnyvale-Santa Clara, CA', '"Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Ubuntu Chromium/36.0.1985.125 Chrome/36.0.1985.125 Safari/537.36"')
# (1543552590796, 26, 'free', None, None, 1068, 'San Jose-Sunnyvale-Santa Clara, CA', '"Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Ubuntu Chromium/36.0.1985.125 Chrome/36.0.1985.125 Safari/537.36"')
# (1543552925796, 49, 'paid', None, None, 1079, 'San Francisco-Oakland-Hayward, CA', 'Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20100101 Firefox/31.0')
# (1543553163796, 49, 'paid', None, None, 1079, 'San Francisco-Oakland-Hayward, CA', 'Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20100101 Firefox/31.0')
# (1543553509796, 49, 'paid', None, None, 1079, 'San Francisco-Oakland-Hayward, CA', 'Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20100101 Firefox/31.0')
# (1543553771796, 57, 'free', None, None, 1020, 'San Antonio-New Braunfels, TX', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_6_8) AppleWebKit/534.59.10 (KHTML, like Gecko) Version/5.1.9 Safari/534.59.10"')
# (1543553823796, 49, 'paid', None, None, 1079, 'San Francisco-Oakland-Hayward, CA', 'Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20100101 Firefox/31.0')
# (1543554186796, 49, 'paid', None, None, 1079, 'San Francisco-Oakland-Hayward, CA', 'Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20100101 Firefox/31.0')
# (1543554392796, 49, 'paid', None, None, 1079, 'San Francisco-Oakland-Hayward, CA', 'Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20100101 Firefox/31.0')
# (1543554669796, 49, 'paid', None, None, 1079, 'San Francisco-Oakland-Hayward, CA', 'Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20100101 Firefox/31.0')
# (1543554740796, 30, 'paid', None, None, 884, 'San Jose-Sunnyvale-Santa Clara, CA', 'Mozilla/5.0 (Windows NT 6.1; WOW64; rv:31.0) Gecko/20100101 Firefox/31.0')
# (1543554912796, 49, 'paid', None, None, 1079, 'San Francisco-Oakland-Hayward, CA', 'Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20100101 Firefox/31.0')
# (1543555014796, 30, 'paid', None, None, 884, 'San Jose-Sunnyvale-Santa Clara, CA', 'Mozilla/5.0 (Windows NT 6.1; WOW64; rv:31.0) Gecko/20100101 Firefox/31.0')
# (1543555175796, 49, 'paid', None, None, 1079, 'San Francisco-Oakland-Hayward, CA', 'Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20100101 Firefox/31.0')
# (1543555254796, 30, 'paid', None, None, 884, 'San Jose-Sunnyvale-Santa Clara, CA', 'Mozilla/5.0 (Windows NT 6.1; WOW64; rv:31.0) Gecko/20100101 Firefox/31.0')
# (1543555414796, 49, 'paid', None, None, 1079, 'San Francisco-Oakland-Hayward, CA', 'Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20100101 Firefox/31.0')
# (1543555485796, 30, 'paid', None, None, 884, 'San Jose-Sunnyvale-Santa Clara, CA', 'Mozilla/5.0 (Windows NT 6.1; WOW64; rv:31.0) Gecko/20100101 Firefox/31.0')
# (1543555708796, 49, 'paid', None, None, 1079, 'San Francisco-Oakland-Hayward, CA', 'Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20100101 Firefox/31.0')
# (1543555744796, 30, 'paid', None, None, 884, 'San Jose-Sunnyvale-Santa Clara, CA', 'Mozilla/5.0 (Windows NT 6.1; WOW64; rv:31.0) Gecko/20100101 Firefox/31.0')
# (1543555885796, 92, 'free', None, None, 1006, 'Palestine, TX', 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10.9; rv:31.0) Gecko/20100101 Firefox/31.0')
# (1543555904796, 49, 'paid', None, None, 1079, 'San Francisco-Oakland-Hayward, CA', 'Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20100101 Firefox/31.0')
# (1543555967796, 30, 'paid', None, None, 884, 'San Jose-Sunnyvale-Santa Clara, CA', 'Mozilla/5.0 (Windows NT 6.1; WOW64; rv:31.0) Gecko/20100101 Firefox/31.0')
# (1543556163796, 30, 'paid', None, None, 884, 'San Jose-Sunnyvale-Santa Clara, CA', 'Mozilla/5.0 (Windows NT 6.1; WOW64; rv:31.0) Gecko/20100101 Firefox/31.0')
# (1543556205796, 49, 'paid', None, None, 1079, 'San Francisco-Oakland-Hayward, CA', 'Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20100101 Firefox/31.0')
# (1543556379796, 30, 'paid', None, None, 884, 'San Jose-Sunnyvale-Santa Clara, CA', 'Mozilla/5.0 (Windows NT 6.1; WOW64; rv:31.0) Gecko/20100101 Firefox/31.0')
# (1543556431796, 49, 'paid', None, None, 1079, 'San Francisco-Oakland-Hayward, CA', 'Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20100101 Firefox/31.0')
# (1543556584796, 30, 'paid', None, None, 884, 'San Jose-Sunnyvale-Santa Clara, CA', 'Mozilla/5.0 (Windows NT 6.1; WOW64; rv:31.0) Gecko/20100101 Firefox/31.0')
# (1543556636796, 49, 'paid', None, None, 1079, 'San Francisco-Oakland-Hayward, CA', 'Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20100101 Firefox/31.0')
# (1543556761796, 30, 'paid', None, None, 884, 'San Jose-Sunnyvale-Santa Clara, CA', 'Mozilla/5.0 (Windows NT 6.1; WOW64; rv:31.0) Gecko/20100101 Firefox/31.0')
# (1543556936796, 49, 'paid', None, None, 1079, 'San Francisco-Oakland-Hayward, CA', 'Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20100101 Firefox/31.0')
# (1543557007796, 30, 'paid', None, None, 884, 'San Jose-Sunnyvale-Santa Clara, CA', 'Mozilla/5.0 (Windows NT 6.1; WOW64; rv:31.0) Gecko/20100101 Firefox/31.0')
# (1543557259796, 30, 'paid', None, None, 884, 'San Jose-Sunnyvale-Santa Clara, CA', 'Mozilla/5.0 (Windows NT 6.1; WOW64; rv:31.0) Gecko/20100101 Firefox/31.0')
# (1543557431796, 49, 'paid', None, None, 1079, 'San Francisco-Oakland-Hayward, CA', 'Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20100101 Firefox/31.0')
# (1543557481796, 30, 'paid', None, None, 884, 'San Jose-Sunnyvale-Santa Clara, CA', 'Mozilla/5.0 (Windows NT 6.1; WOW64; rv:31.0) Gecko/20100101 Firefox/31.0')
# (1543557700796, 49, 'paid', None, None, 1079, 'San Francisco-Oakland-Hayward, CA', 'Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20100101 Firefox/31.0')
# (1543557890796, 30, 'paid', None, None, 884, 'San Jose-Sunnyvale-Santa Clara, CA', 'Mozilla/5.0 (Windows NT 6.1; WOW64; rv:31.0) Gecko/20100101 Firefox/31.0')
# (1543557895796, 49, 'paid', None, None, 1079, 'San Francisco-Oakland-Hayward, CA', 'Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20100101 Firefox/31.0')
# (1543558077796, 30, 'paid', None, None, 884, 'San Jose-Sunnyvale-Santa Clara, CA', 'Mozilla/5.0 (Windows NT 6.1; WOW64; rv:31.0) Gecko/20100101 Firefox/31.0')
# (1543558218796, 49, 'paid', None, None, 1079, 'San Francisco-Oakland-Hayward, CA', 'Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20100101 Firefox/31.0')
# (1543558374796, 30, 'paid', None, None, 884, 'San Jose-Sunnyvale-Santa Clara, CA', 'Mozilla/5.0 (Windows NT 6.1; WOW64; rv:31.0) Gecko/20100101 Firefox/31.0')
# (1543558403796, 49, 'paid', None, None, 1079, 'San Francisco-Oakland-Hayward, CA', 'Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20100101 Firefox/31.0')
# (1543558442796, 30, 'paid', None, None, 884, 'San Jose-Sunnyvale-Santa Clara, CA', 'Mozilla/5.0 (Windows NT 6.1; WOW64; rv:31.0) Gecko/20100101 Firefox/31.0')
# (1543558595796, 49, 'paid', None, None, 1079, 'San Francisco-Oakland-Hayward, CA', 'Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20100101 Firefox/31.0')
# (1543558708796, 30, 'paid', None, None, 884, 'San Jose-Sunnyvale-Santa Clara, CA', 'Mozilla/5.0 (Windows NT 6.1; WOW64; rv:31.0) Gecko/20100101 Firefox/31.0')
# (1543558891796, 49, 'paid', None, None, 1079, 'San Francisco-Oakland-Hayward, CA', 'Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20100101 Firefox/31.0')
# (1543559185796, 49, 'paid', None, None, 1079, 'San Francisco-Oakland-Hayward, CA', 'Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20100101 Firefox/31.0')
# (1543559435796, 49, 'paid', None, None, 1079, 'San Francisco-Oakland-Hayward, CA', 'Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20100101 Firefox/31.0')
# (1543559636796, 49, 'paid', None, None, 1079, 'San Francisco-Oakland-Hayward, CA', 'Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20100101 Firefox/31.0')
# (1543559834796, 49, 'paid', None, None, 1079, 'San Francisco-Oakland-Hayward, CA', 'Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20100101 Firefox/31.0')
# (1543560047796, 49, 'paid', None, None, 1079, 'San Francisco-Oakland-Hayward, CA', 'Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20100101 Firefox/31.0')
# (1543560267796, 49, 'paid', None, None, 1079, 'San Francisco-Oakland-Hayward, CA', 'Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20100101 Firefox/31.0')
# (1543560508796, 49, 'paid', None, None, 1079, 'San Francisco-Oakland-Hayward, CA', 'Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20100101 Firefox/31.0')
# (1543560751796, 49, 'paid', None, None, 1079, 'San Francisco-Oakland-Hayward, CA', 'Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20100101 Firefox/31.0')
# (1543560882796, 49, 'paid', None, None, 1079, 'San Francisco-Oakland-Hayward, CA', 'Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20100101 Firefox/31.0')
# (1543561118796, 49, 'paid', None, None, 1079, 'San Francisco-Oakland-Hayward, CA', 'Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20100101 Firefox/31.0')
# (1543561343796, 49, 'paid', None, None, 1079, 'San Francisco-Oakland-Hayward, CA', 'Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20100101 Firefox/31.0')
# (1543561715796, 49, 'paid', None, None, 1079, 'San Francisco-Oakland-Hayward, CA', 'Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20100101 Firefox/31.0')
# (1543562124796, 49, 'paid', None, None, 1079, 'San Francisco-Oakland-Hayward, CA', 'Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20100101 Firefox/31.0')
# (1543562311796, 49, 'paid', None, None, 1079, 'San Francisco-Oakland-Hayward, CA', 'Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20100101 Firefox/31.0')
# (1543562532796, 49, 'paid', None, None, 1079, 'San Francisco-Oakland-Hayward, CA', 'Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20100101 Firefox/31.0')
# (1543562685796, 49, 'paid', None, None, 1079, 'San Francisco-Oakland-Hayward, CA', 'Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20100101 Firefox/31.0')
# (1543562909796, 49, 'paid', None, None, 1079, 'San Francisco-Oakland-Hayward, CA', 'Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20100101 Firefox/31.0')
# (1543562949796, 74, 'free', None, None, 1082, 'Youngstown-Warren-Boardman, OH-PA', '"Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"')
# (1543563099796, 49, 'paid', None, None, 1079, 'San Francisco-Oakland-Hayward, CA', 'Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20100101 Firefox/31.0')
# (1543563383796, 49, 'paid', None, None, 1079, 'San Francisco-Oakland-Hayward, CA', 'Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20100101 Firefox/31.0')
# (1543563531796, 49, 'paid', None, None, 1079, 'San Francisco-Oakland-Hayward, CA', 'Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20100101 Firefox/31.0')
# (1543563757796, 49, 'paid', None, None, 1079, 'San Francisco-Oakland-Hayward, CA', 'Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20100101 Firefox/31.0')
# (1543564025796, 49, 'paid', None, None, 1079, 'San Francisco-Oakland-Hayward, CA', 'Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20100101 Firefox/31.0')
# (1543564194796, 49, 'paid', None, None, 1079, 'San Francisco-Oakland-Hayward, CA', 'Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20100101 Firefox/31.0')
# (1543565771796, 88, 'paid', None, None, 1075, 'Sacramento--Roseville--Arden-Arcade, CA', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"')
# (1543566012796, 88, 'paid', None, None, 1075, 'Sacramento--Roseville--Arden-Arcade, CA', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"')
# (1543566117796, 88, 'paid', None, None, 1075, 'Sacramento--Roseville--Arden-Arcade, CA', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"')
# (1543566367796, 88, 'paid', None, None, 1075, 'Sacramento--Roseville--Arden-Arcade, CA', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"')
# (1543566598796, 88, 'paid', None, None, 1075, 'Sacramento--Roseville--Arden-Arcade, CA', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"')
# (1543566763796, 88, 'paid', None, None, 1075, 'Sacramento--Roseville--Arden-Arcade, CA', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"')
# (1543567118796, 88, 'paid', None, None, 1075, 'Sacramento--Roseville--Arden-Arcade, CA', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"')
# (1543567581796, 88, 'paid', None, None, 1075, 'Sacramento--Roseville--Arden-Arcade, CA', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"')
# (1543572774796, 36, 'paid', None, None, 998, 'Janesville-Beloit, WI', '"Mozilla/5.0 (Windows NT 5.1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"')
# (1543573087796, 36, 'paid', None, None, 998, 'Janesville-Beloit, WI', '"Mozilla/5.0 (Windows NT 5.1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"')
# (1543573373796, 36, 'paid', None, None, 998, 'Janesville-Beloit, WI', '"Mozilla/5.0 (Windows NT 5.1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"')
# (1543573628796, 36, 'paid', None, None, 998, 'Janesville-Beloit, WI', '"Mozilla/5.0 (Windows NT 5.1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"')
# (1543573853796, 36, 'paid', None, None, 998, 'Janesville-Beloit, WI', '"Mozilla/5.0 (Windows NT 5.1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"')
# (1543574118796, 36, 'paid', None, None, 998, 'Janesville-Beloit, WI', '"Mozilla/5.0 (Windows NT 5.1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"')
# (1543574334796, 36, 'paid', None, None, 998, 'Janesville-Beloit, WI', '"Mozilla/5.0 (Windows NT 5.1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"')
# (1543574529796, 36, 'paid', None, None, 998, 'Janesville-Beloit, WI', '"Mozilla/5.0 (Windows NT 5.1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"')
# (1543574766796, 36, 'paid', None, None, 998, 'Janesville-Beloit, WI', '"Mozilla/5.0 (Windows NT 5.1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"')
# (1543574980796, 36, 'paid', None, None, 998, 'Janesville-Beloit, WI', '"Mozilla/5.0 (Windows NT 5.1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"')
# (1543575245796, 36, 'paid', None, None, 998, 'Janesville-Beloit, WI', '"Mozilla/5.0 (Windows NT 5.1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"')
# (1543575385796, 92, 'free', None, None, 1092, 'Palestine, TX', 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10.9; rv:31.0) Gecko/20100101 Firefox/31.0')
# (1543575563796, 36, 'paid', None, None, 998, 'Janesville-Beloit, WI', '"Mozilla/5.0 (Windows NT 5.1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"')
# (1543575601796, 92, 'free', None, None, 1092, 'Palestine, TX', 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10.9; rv:31.0) Gecko/20100101 Firefox/31.0')
# (1543575978796, 92, 'free', None, None, 1092, 'Palestine, TX', 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10.9; rv:31.0) Gecko/20100101 Firefox/31.0')
# (1543576189796, 92, 'free', None, None, 1092, 'Palestine, TX', 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10.9; rv:31.0) Gecko/20100101 Firefox/31.0')
# (1543576218796, 36, 'paid', None, None, 998, 'Janesville-Beloit, WI', '"Mozilla/5.0 (Windows NT 5.1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"')
# (1543576387796, 36, 'paid', None, None, 998, 'Janesville-Beloit, WI', '"Mozilla/5.0 (Windows NT 5.1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"')
# (1543576570796, 36, 'paid', None, None, 998, 'Janesville-Beloit, WI', '"Mozilla/5.0 (Windows NT 5.1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"')
# (1543576803796, 36, 'paid', None, None, 998, 'Janesville-Beloit, WI', '"Mozilla/5.0 (Windows NT 5.1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"')
# (1543577024796, 36, 'paid', None, None, 998, 'Janesville-Beloit, WI', '"Mozilla/5.0 (Windows NT 5.1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"')
# (1543577296796, 36, 'paid', None, None, 998, 'Janesville-Beloit, WI', '"Mozilla/5.0 (Windows NT 5.1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"')
# (1543577524796, 36, 'paid', None, None, 998, 'Janesville-Beloit, WI', '"Mozilla/5.0 (Windows NT 5.1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"')
# (1543577843796, 36, 'paid', None, None, 998, 'Janesville-Beloit, WI', '"Mozilla/5.0 (Windows NT 5.1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"')
# (1543578063796, 36, 'paid', None, None, 998, 'Janesville-Beloit, WI', '"Mozilla/5.0 (Windows NT 5.1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"')
# (1543578383796, 36, 'paid', None, None, 998, 'Janesville-Beloit, WI', '"Mozilla/5.0 (Windows NT 5.1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"')
# (1543578582796, 36, 'paid', None, None, 998, 'Janesville-Beloit, WI', '"Mozilla/5.0 (Windows NT 5.1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"')
# (1543579857796, 12, 'free', None, None, 1078, 'New York-Newark-Jersey City, NY-NJ-PA', 'Mozilla/5.0 (Windows NT 6.1; rv:31.0) Gecko/20100101 Firefox/31.0')
# (1543581078796, 49, 'paid', None, None, 1096, 'San Francisco-Oakland-Hayward, CA', 'Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20100101 Firefox/31.0')
# (1543581287796, 49, 'paid', None, None, 1096, 'San Francisco-Oakland-Hayward, CA', 'Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20100101 Firefox/31.0')
# (1543581576796, 49, 'paid', None, None, 1096, 'San Francisco-Oakland-Hayward, CA', 'Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20100101 Firefox/31.0')
# (1543582073796, 49, 'paid', None, None, 1096, 'San Francisco-Oakland-Hayward, CA', 'Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20100101 Firefox/31.0')
# (1543582370796, 49, 'paid', None, None, 1096, 'San Francisco-Oakland-Hayward, CA', 'Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20100101 Firefox/31.0')
# (1543582625796, 49, 'paid', None, None, 1096, 'San Francisco-Oakland-Hayward, CA', 'Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20100101 Firefox/31.0')
# (1543582673796, 61, 'free', None, None, 1064, 'Houston-The Woodlands-Sugar Land, TX', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.77.4 (KHTML, like Gecko) Version/7.0.5 Safari/537.77.4"')
# (1543582902796, 49, 'paid', None, None, 1096, 'San Francisco-Oakland-Hayward, CA', 'Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20100101 Firefox/31.0')
# (1543583154796, 49, 'paid', None, None, 1096, 'San Francisco-Oakland-Hayward, CA', 'Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20100101 Firefox/31.0')
# (1543583416796, 49, 'paid', None, None, 1096, 'San Francisco-Oakland-Hayward, CA', 'Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20100101 Firefox/31.0')
# (1543583625796, 49, 'paid', None, None, 1096, 'San Francisco-Oakland-Hayward, CA', 'Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20100101 Firefox/31.0')
# (1543583845796, 49, 'paid', None, None, 1096, 'San Francisco-Oakland-Hayward, CA', 'Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20100101 Firefox/31.0')
# (1543584030796, 49, 'paid', None, None, 1096, 'San Francisco-Oakland-Hayward, CA', 'Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20100101 Firefox/31.0')
# (1543584044796, 43, 'free', None, None, 618, 'San Antonio-New Braunfels, TX', '"Mozilla/5.0 (Windows NT 5.1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"')
# (1543584469796, 49, 'paid', None, None, 1096, 'San Francisco-Oakland-Hayward, CA', 'Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20100101 Firefox/31.0')
# (1543584688796, 49, 'paid', None, None, 1096, 'San Francisco-Oakland-Hayward, CA', 'Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20100101 Firefox/31.0')
# (1543584889796, 49, 'paid', None, None, 1096, 'San Francisco-Oakland-Hayward, CA', 'Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20100101 Firefox/31.0')
# (1543585122796, 49, 'paid', None, None, 1096, 'San Francisco-Oakland-Hayward, CA', 'Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20100101 Firefox/31.0')
# (1543585311796, 49, 'paid', None, None, 1096, 'San Francisco-Oakland-Hayward, CA', 'Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20100101 Firefox/31.0')
# (1543585420796, 85, 'paid', None, None, 977, 'Red Bluff, CA', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_0) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"')
# (1543585520796, 49, 'paid', None, None, 1096, 'San Francisco-Oakland-Hayward, CA', 'Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20100101 Firefox/31.0')
# (1543585687796, 85, 'paid', None, None, 977, 'Red Bluff, CA', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_0) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"')
# (1543585735796, 49, 'paid', None, None, 1096, 'San Francisco-Oakland-Hayward, CA', 'Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20100101 Firefox/31.0')
# (1543585957796, 49, 'paid', None, None, 1096, 'San Francisco-Oakland-Hayward, CA', 'Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20100101 Firefox/31.0')
# (1543585975796, 85, 'paid', None, None, 977, 'Red Bluff, CA', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_0) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"')
# (1543586196796, 49, 'paid', None, None, 1096, 'San Francisco-Oakland-Hayward, CA', 'Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20100101 Firefox/31.0')
# (1543586241796, 85, 'paid', None, None, 977, 'Red Bluff, CA', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_0) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"')
# (1543586244796, 50, 'free', None, None, 1050, 'New Haven-Milford, CT', '"Mozilla/5.0 (Windows NT 6.3; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"')
# (1543586371796, 50, 'free', None, None, 1050, 'New Haven-Milford, CT', '"Mozilla/5.0 (Windows NT 6.3; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"')
# (1543586438796, 26, 'free', None, None, 1090, 'San Jose-Sunnyvale-Santa Clara, CA', '"Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Ubuntu Chromium/36.0.1985.125 Chrome/36.0.1985.125 Safari/537.36"')
# (1543586502796, 85, 'paid', None, None, 977, 'Red Bluff, CA', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_0) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"')
# (1543586503796, 49, 'paid', None, None, 1096, 'San Francisco-Oakland-Hayward, CA', 'Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20100101 Firefox/31.0')
# (1543586601796, 50, 'free', None, None, 1050, 'New Haven-Milford, CT', '"Mozilla/5.0 (Windows NT 6.3; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"')
# (1543586687796, 26, 'free', None, None, 1090, 'San Jose-Sunnyvale-Santa Clara, CA', '"Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Ubuntu Chromium/36.0.1985.125 Chrome/36.0.1985.125 Safari/537.36"')
# (1543586803796, 49, 'paid', None, None, 1096, 'San Francisco-Oakland-Hayward, CA', 'Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20100101 Firefox/31.0')
# (1543586876796, 85, 'paid', None, None, 977, 'Red Bluff, CA', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_0) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"')
# (1543587001796, 49, 'paid', None, None, 1096, 'San Francisco-Oakland-Hayward, CA', 'Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20100101 Firefox/31.0')
# (1543587085796, 85, 'paid', None, None, 977, 'Red Bluff, CA', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_0) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"')
# (1543587136796, 49, 'paid', None, None, 1096, 'San Francisco-Oakland-Hayward, CA', 'Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20100101 Firefox/31.0')
# (1543587325796, 85, 'paid', None, None, 977, 'Red Bluff, CA', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_0) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"')
# (1543587396796, 49, 'paid', None, None, 1096, 'San Francisco-Oakland-Hayward, CA', 'Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20100101 Firefox/31.0')
# (1543587588796, 85, 'paid', None, None, 977, 'Red Bluff, CA', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_0) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"')
# (1543587705796, 49, 'paid', None, None, 1096, 'San Francisco-Oakland-Hayward, CA', 'Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20100101 Firefox/31.0')
# (1543587842796, 49, 'paid', None, None, 1096, 'San Francisco-Oakland-Hayward, CA', 'Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20100101 Firefox/31.0')
# (1543588062796, 85, 'paid', None, None, 977, 'Red Bluff, CA', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_0) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"')
# (1543588106796, 49, 'paid', None, None, 1096, 'San Francisco-Oakland-Hayward, CA', 'Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20100101 Firefox/31.0')
# (1543588275796, 85, 'paid', None, None, 977, 'Red Bluff, CA', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_0) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"')
# (1543588419796, 49, 'paid', None, None, 1096, 'San Francisco-Oakland-Hayward, CA', 'Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20100101 Firefox/31.0')
# (1543588433796, 101, 'free', None, None, 1060, 'New Orleans-Metairie, LA', '"Mozilla/5.0 (Windows NT 6.3; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"')
# (1543588567796, 85, 'paid', None, None, 977, 'Red Bluff, CA', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_0) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"')
# (1543588676796, 101, 'free', None, None, 1060, 'New Orleans-Metairie, LA', '"Mozilla/5.0 (Windows NT 6.3; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"')
# (1543588717796, 49, 'paid', None, None, 1096, 'San Francisco-Oakland-Hayward, CA', 'Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20100101 Firefox/31.0')
# (1543588866796, 16, 'paid', None, None, 1076, 'Birmingham-Hoover, AL', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.77.4 (KHTML, like Gecko) Version/7.0.5 Safari/537.77.4"')
# (1543588921796, 85, 'paid', None, None, 977, 'Red Bluff, CA', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_0) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"')
# (1543588958796, 49, 'paid', None, None, 1096, 'San Francisco-Oakland-Hayward, CA', 'Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20100101 Firefox/31.0')
# (1543588965796, 101, 'free', None, None, 1060, 'New Orleans-Metairie, LA', '"Mozilla/5.0 (Windows NT 6.3; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"')
# (1543589030796, 101, 'free', None, None, 1060, 'New Orleans-Metairie, LA', '"Mozilla/5.0 (Windows NT 6.3; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"')
# (1543589113796, 16, 'paid', None, None, 1076, 'Birmingham-Hoover, AL', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.77.4 (KHTML, like Gecko) Version/7.0.5 Safari/537.77.4"')
# (1543589203796, 85, 'paid', None, None, 977, 'Red Bluff, CA', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_0) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"')
# (1543589255796, 101, 'free', None, None, 1060, 'New Orleans-Metairie, LA', '"Mozilla/5.0 (Windows NT 6.3; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"')
# (1543589377796, 16, 'paid', None, None, 1076, 'Birmingham-Hoover, AL', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.77.4 (KHTML, like Gecko) Version/7.0.5 Safari/537.77.4"')
# (1543589497796, 101, 'free', None, None, 1060, 'New Orleans-Metairie, LA', '"Mozilla/5.0 (Windows NT 6.3; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"')
# (1543589524796, 85, 'paid', None, None, 977, 'Red Bluff, CA', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_0) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"')
# (1543589613796, 16, 'paid', None, None, 1076, 'Birmingham-Hoover, AL', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.77.4 (KHTML, like Gecko) Version/7.0.5 Safari/537.77.4"')
# (1543589725796, 85, 'paid', None, None, 977, 'Red Bluff, CA', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_0) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"')
# (1543589872796, 85, 'paid', None, None, 977, 'Red Bluff, CA', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_0) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"')
# (1543589971796, 88, 'paid', None, None, 1097, 'Sacramento--Roseville--Arden-Arcade, CA', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"')
# (1543589972796, 16, 'paid', None, None, 1076, 'Birmingham-Hoover, AL', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.77.4 (KHTML, like Gecko) Version/7.0.5 Safari/537.77.4"')
# (1543590066796, 85, 'paid', None, None, 977, 'Red Bluff, CA', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_0) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"')
# (1543590162796, 16, 'paid', None, None, 1076, 'Birmingham-Hoover, AL', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.77.4 (KHTML, like Gecko) Version/7.0.5 Safari/537.77.4"')
# (1543590347796, 88, 'paid', None, None, 1097, 'Sacramento--Roseville--Arden-Arcade, CA', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"')
# (1543590356796, 85, 'paid', None, None, 977, 'Red Bluff, CA', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_0) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"')
# (1543590398796, 16, 'paid', None, None, 1076, 'Birmingham-Hoover, AL', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.77.4 (KHTML, like Gecko) Version/7.0.5 Safari/537.77.4"')
# (1543590541796, 88, 'paid', None, None, 1097, 'Sacramento--Roseville--Arden-Arcade, CA', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"')
# (1543590607796, 85, 'paid', None, None, 977, 'Red Bluff, CA', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_0) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"')
# (1543590707796, 16, 'paid', None, None, 1076, 'Birmingham-Hoover, AL', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.77.4 (KHTML, like Gecko) Version/7.0.5 Safari/537.77.4"')
# (1543590774796, 36, 'paid', None, None, 1100, 'Janesville-Beloit, WI', '"Mozilla/5.0 (Windows NT 5.1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"')
# (1543590783796, 88, 'paid', None, None, 1097, 'Sacramento--Roseville--Arden-Arcade, CA', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"')
# (1543590875796, 85, 'paid', None, None, 977, 'Red Bluff, CA', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_0) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"')
# (1543590905796, 16, 'paid', None, None, 1076, 'Birmingham-Hoover, AL', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.77.4 (KHTML, like Gecko) Version/7.0.5 Safari/537.77.4"')
# (1543590962796, 36, 'paid', None, None, 1100, 'Janesville-Beloit, WI', '"Mozilla/5.0 (Windows NT 5.1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"')
# (1543591027796, 85, 'paid', None, None, 977, 'Red Bluff, CA', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_0) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"')
# (1543591138796, 16, 'paid', None, None, 1076, 'Birmingham-Hoover, AL', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.77.4 (KHTML, like Gecko) Version/7.0.5 Safari/537.77.4"')
# (1543591289796, 85, 'paid', None, None, 977, 'Red Bluff, CA', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_0) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"')
# (1543591329796, 36, 'paid', None, None, 1100, 'Janesville-Beloit, WI', '"Mozilla/5.0 (Windows NT 5.1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"')
# (1543591374796, 16, 'paid', None, None, 1076, 'Birmingham-Hoover, AL', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.77.4 (KHTML, like Gecko) Version/7.0.5 Safari/537.77.4"')
# (1543591485796, 85, 'paid', None, None, 977, 'Red Bluff, CA', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_0) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"')
# (1543591559796, 36, 'paid', None, None, 1100, 'Janesville-Beloit, WI', '"Mozilla/5.0 (Windows NT 5.1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"')
# (1543591645796, 16, 'paid', None, None, 1076, 'Birmingham-Hoover, AL', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.77.4 (KHTML, like Gecko) Version/7.0.5 Safari/537.77.4"')
# (1543591710796, 85, 'paid', None, None, 977, 'Red Bluff, CA', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_0) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"')
# (1543591920796, 16, 'paid', None, None, 1076, 'Birmingham-Hoover, AL', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.77.4 (KHTML, like Gecko) Version/7.0.5 Safari/537.77.4"')
# (1543591986796, 85, 'paid', None, None, 977, 'Red Bluff, CA', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_0) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"')
# (1543592227796, 85, 'paid', None, None, 977, 'Red Bluff, CA', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_0) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"')
# (1543592542796, 16, 'paid', None, None, 1076, 'Birmingham-Hoover, AL', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.77.4 (KHTML, like Gecko) Version/7.0.5 Safari/537.77.4"')
# (1543592775796, 16, 'paid', None, None, 1076, 'Birmingham-Hoover, AL', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.77.4 (KHTML, like Gecko) Version/7.0.5 Safari/537.77.4"')
# (1543593008796, 16, 'paid', None, None, 1076, 'Birmingham-Hoover, AL', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.77.4 (KHTML, like Gecko) Version/7.0.5 Safari/537.77.4"')
# (1543593062796, 49, 'paid', None, None, 1096, 'San Francisco-Oakland-Hayward, CA', 'Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20100101 Firefox/31.0')
# (1543593217796, 16, 'paid', None, None, 1076, 'Birmingham-Hoover, AL', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.77.4 (KHTML, like Gecko) Version/7.0.5 Safari/537.77.4"')
# (1543593263796, 49, 'paid', None, None, 1096, 'San Francisco-Oakland-Hayward, CA', 'Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20100101 Firefox/31.0')
# (1543593462796, 16, 'paid', None, None, 1076, 'Birmingham-Hoover, AL', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.77.4 (KHTML, like Gecko) Version/7.0.5 Safari/537.77.4"')
# (1543593531796, 49, 'paid', None, None, 1096, 'San Francisco-Oakland-Hayward, CA', 'Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20100101 Firefox/31.0')
# (1543593631796, 16, 'paid', None, None, 1076, 'Birmingham-Hoover, AL', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.77.4 (KHTML, like Gecko) Version/7.0.5 Safari/537.77.4"')
# (1543593786796, 49, 'paid', None, None, 1096, 'San Francisco-Oakland-Hayward, CA', 'Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20100101 Firefox/31.0')
# (1543593975796, 49, 'paid', None, None, 1096, 'San Francisco-Oakland-Hayward, CA', 'Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20100101 Firefox/31.0')
# (1543594072796, 16, 'paid', None, None, 1076, 'Birmingham-Hoover, AL', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.77.4 (KHTML, like Gecko) Version/7.0.5 Safari/537.77.4"')
# (1543594156796, 49, 'paid', None, None, 1096, 'San Francisco-Oakland-Hayward, CA', 'Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20100101 Firefox/31.0')
# (1543594323796, 16, 'paid', None, None, 1076, 'Birmingham-Hoover, AL', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.77.4 (KHTML, like Gecko) Version/7.0.5 Safari/537.77.4"')
# (1543594388796, 49, 'paid', None, None, 1096, 'San Francisco-Oakland-Hayward, CA', 'Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20100101 Firefox/31.0')
# (1543594519796, 16, 'paid', None, None, 1076, 'Birmingham-Hoover, AL', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.77.4 (KHTML, like Gecko) Version/7.0.5 Safari/537.77.4"')
# (1543594665796, 49, 'paid', None, None, 1096, 'San Francisco-Oakland-Hayward, CA', 'Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20100101 Firefox/31.0')
# (1543594698796, 78, 'free', None, None, 1059, 'Indianapolis-Carmel-Anderson, IN', 'Mozilla/5.0 (Windows NT 6.1; rv:31.0) Gecko/20100101 Firefox/31.0')
# (1543594804796, 16, 'paid', None, None, 1076, 'Birmingham-Hoover, AL', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.77.4 (KHTML, like Gecko) Version/7.0.5 Safari/537.77.4"')
# (1543594883796, 78, 'free', None, None, 1059, 'Indianapolis-Carmel-Anderson, IN', 'Mozilla/5.0 (Windows NT 6.1; rv:31.0) Gecko/20100101 Firefox/31.0')
# (1543594893796, 49, 'paid', None, None, 1096, 'San Francisco-Oakland-Hayward, CA', 'Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20100101 Firefox/31.0')
# (1543595117796, 16, 'paid', None, None, 1076, 'Birmingham-Hoover, AL', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.77.4 (KHTML, like Gecko) Version/7.0.5 Safari/537.77.4"')
# (1543595229796, 49, 'paid', None, None, 1096, 'San Francisco-Oakland-Hayward, CA', 'Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20100101 Firefox/31.0')
# (1543595485796, 16, 'paid', None, None, 1076, 'Birmingham-Hoover, AL', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.77.4 (KHTML, like Gecko) Version/7.0.5 Safari/537.77.4"')
# (1543595652796, 16, 'paid', None, None, 1076, 'Birmingham-Hoover, AL', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.77.4 (KHTML, like Gecko) Version/7.0.5 Safari/537.77.4"')
# (1543595757796, 33, 'free', None, None, 1026, 'Eugene, OR', '"Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.125 Safari/537.36"')
# (1543595890796, 16, 'paid', None, None, 1076, 'Birmingham-Hoover, AL', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.77.4 (KHTML, like Gecko) Version/7.0.5 Safari/537.77.4"')
# (1543595952796, 33, 'free', None, None, 1026, 'Eugene, OR', '"Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.125 Safari/537.36"')
# (1543596083796, 16, 'paid', None, None, 1076, 'Birmingham-Hoover, AL', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.77.4 (KHTML, like Gecko) Version/7.0.5 Safari/537.77.4"')
# (1543596208796, 33, 'free', None, None, 1026, 'Eugene, OR', '"Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.125 Safari/537.36"')
# (1543596328796, 16, 'paid', None, None, 1076, 'Birmingham-Hoover, AL', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.77.4 (KHTML, like Gecko) Version/7.0.5 Safari/537.77.4"')
# (1543596546796, 16, 'paid', None, None, 1076, 'Birmingham-Hoover, AL', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.77.4 (KHTML, like Gecko) Version/7.0.5 Safari/537.77.4"')
# (1543596702796, 16, 'paid', None, None, 1076, 'Birmingham-Hoover, AL', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.77.4 (KHTML, like Gecko) Version/7.0.5 Safari/537.77.4"')
# (1543596941796, 16, 'paid', None, None, 1076, 'Birmingham-Hoover, AL', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.77.4 (KHTML, like Gecko) Version/7.0.5 Safari/537.77.4"')
# (1543597146796, 16, 'paid', None, None, 1076, 'Birmingham-Hoover, AL', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.77.4 (KHTML, like Gecko) Version/7.0.5 Safari/537.77.4"')
# (1543597383796, 16, 'paid', None, None, 1076, 'Birmingham-Hoover, AL', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.77.4 (KHTML, like Gecko) Version/7.0.5 Safari/537.77.4"')
# (1543597642796, 16, 'paid', None, None, 1076, 'Birmingham-Hoover, AL', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.77.4 (KHTML, like Gecko) Version/7.0.5 Safari/537.77.4"')
# (1543597876796, 16, 'paid', None, None, 1076, 'Birmingham-Hoover, AL', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.77.4 (KHTML, like Gecko) Version/7.0.5 Safari/537.77.4"')
# (1543598174796, 49, 'paid', None, None, 1114, 'San Francisco-Oakland-Hayward, CA', 'Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20100101 Firefox/31.0')
# (1543598368796, 49, 'paid', None, None, 1114, 'San Francisco-Oakland-Hayward, CA', 'Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20100101 Firefox/31.0')
# (1543598398796, 16, 'paid', None, None, 1076, 'Birmingham-Hoover, AL', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.77.4 (KHTML, like Gecko) Version/7.0.5 Safari/537.77.4"')
# (1543598521796, 49, 'paid', None, None, 1114, 'San Francisco-Oakland-Hayward, CA', 'Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20100101 Firefox/31.0')
# (1543598647796, 16, 'paid', None, None, 1076, 'Birmingham-Hoover, AL', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.77.4 (KHTML, like Gecko) Version/7.0.5 Safari/537.77.4"')
# (1543598736796, 49, 'paid', None, None, 1114, 'San Francisco-Oakland-Hayward, CA', 'Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20100101 Firefox/31.0')
# (1543598917796, 49, 'paid', None, None, 1114, 'San Francisco-Oakland-Hayward, CA', 'Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20100101 Firefox/31.0')
# (1543599027796, 16, 'paid', None, None, 1076, 'Birmingham-Hoover, AL', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.77.4 (KHTML, like Gecko) Version/7.0.5 Safari/537.77.4"')
# (1543599084796, 49, 'paid', None, None, 1114, 'San Francisco-Oakland-Hayward, CA', 'Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20100101 Firefox/31.0')
# (1543599267796, 16, 'paid', None, None, 1076, 'Birmingham-Hoover, AL', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.77.4 (KHTML, like Gecko) Version/7.0.5 Safari/537.77.4"')
# (1543599307796, 49, 'paid', None, None, 1114, 'San Francisco-Oakland-Hayward, CA', 'Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20100101 Firefox/31.0')
# (1543599548796, 49, 'paid', None, None, 1114, 'San Francisco-Oakland-Hayward, CA', 'Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20100101 Firefox/31.0')
# (1543599557796, 16, 'paid', None, None, 1076, 'Birmingham-Hoover, AL', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.77.4 (KHTML, like Gecko) Version/7.0.5 Safari/537.77.4"')
# (1543599778796, 16, 'paid', None, None, 1076, 'Birmingham-Hoover, AL', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.77.4 (KHTML, like Gecko) Version/7.0.5 Safari/537.77.4"')
# (1543599840796, 49, 'paid', None, None, 1114, 'San Francisco-Oakland-Hayward, CA', 'Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20100101 Firefox/31.0')
# (1543599941796, 49, 'paid', None, None, 1114, 'San Francisco-Oakland-Hayward, CA', 'Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20100101 Firefox/31.0')
# (1543600033796, 16, 'paid', None, None, 1076, 'Birmingham-Hoover, AL', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.77.4 (KHTML, like Gecko) Version/7.0.5 Safari/537.77.4"')
# (1543600135796, 49, 'paid', None, None, 1114, 'San Francisco-Oakland-Hayward, CA', 'Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20100101 Firefox/31.0')
# (1543600185796, 16, 'paid', None, None, 1076, 'Birmingham-Hoover, AL', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.77.4 (KHTML, like Gecko) Version/7.0.5 Safari/537.77.4"')
# (1543600424796, 16, 'paid', None, None, 1076, 'Birmingham-Hoover, AL', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.77.4 (KHTML, like Gecko) Version/7.0.5 Safari/537.77.4"')
# (1543600483796, 49, 'paid', None, None, 1114, 'San Francisco-Oakland-Hayward, CA', 'Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20100101 Firefox/31.0')
# (1543600644796, 16, 'paid', None, None, 1076, 'Birmingham-Hoover, AL', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.77.4 (KHTML, like Gecko) Version/7.0.5 Safari/537.77.4"')
# (1543600723796, 49, 'paid', None, None, 1114, 'San Francisco-Oakland-Hayward, CA', 'Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20100101 Firefox/31.0')
# (1543600999796, 49, 'paid', None, None, 1114, 'San Francisco-Oakland-Hayward, CA', 'Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20100101 Firefox/31.0')
# (1543601063796, 16, 'paid', None, None, 1076, 'Birmingham-Hoover, AL', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.77.4 (KHTML, like Gecko) Version/7.0.5 Safari/537.77.4"')
# (1543601287796, 49, 'paid', None, None, 1114, 'San Francisco-Oakland-Hayward, CA', 'Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20100101 Firefox/31.0')
# (1543601401796, 16, 'paid', None, None, 1076, 'Birmingham-Hoover, AL', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.77.4 (KHTML, like Gecko) Version/7.0.5 Safari/537.77.4"')
# (1543601616796, 49, 'paid', None, None, 1114, 'San Francisco-Oakland-Hayward, CA', 'Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20100101 Firefox/31.0')
# (1543601696796, 16, 'paid', None, None, 1076, 'Birmingham-Hoover, AL', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.77.4 (KHTML, like Gecko) Version/7.0.5 Safari/537.77.4"')
# (1543601780796, 91, 'free', None, None, 1085, 'Dallas-Fort Worth-Arlington, TX', 'Mozilla/5.0 (compatible; MSIE 10.0; Windows NT 6.2; WOW64; Trident/6.0)')
# (1543601943796, 16, 'paid', None, None, 1076, 'Birmingham-Hoover, AL', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.77.4 (KHTML, like Gecko) Version/7.0.5 Safari/537.77.4"')
# (1543601973796, 49, 'paid', None, None, 1114, 'San Francisco-Oakland-Hayward, CA', 'Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20100101 Firefox/31.0')
# (1543602079796, 91, 'free', None, None, 1085, 'Dallas-Fort Worth-Arlington, TX', 'Mozilla/5.0 (compatible; MSIE 10.0; Windows NT 6.2; WOW64; Trident/6.0)')
# (1543602106796, 16, 'paid', None, None, 1076, 'Birmingham-Hoover, AL', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.77.4 (KHTML, like Gecko) Version/7.0.5 Safari/537.77.4"')
# (1543602245796, 49, 'paid', None, None, 1114, 'San Francisco-Oakland-Hayward, CA', 'Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20100101 Firefox/31.0')
# (1543602372796, 16, 'paid', None, None, 1076, 'Birmingham-Hoover, AL', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.77.4 (KHTML, like Gecko) Version/7.0.5 Safari/537.77.4"')
# (1543602488796, 49, 'paid', None, None, 1114, 'San Francisco-Oakland-Hayward, CA', 'Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20100101 Firefox/31.0')
# (1543602542796, 16, 'paid', None, None, 1076, 'Birmingham-Hoover, AL', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.77.4 (KHTML, like Gecko) Version/7.0.5 Safari/537.77.4"')
# (1543602694796, 16, 'paid', None, None, 1076, 'Birmingham-Hoover, AL', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.77.4 (KHTML, like Gecko) Version/7.0.5 Safari/537.77.4"')
# (1543602766796, 49, 'paid', None, None, 1114, 'San Francisco-Oakland-Hayward, CA', 'Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20100101 Firefox/31.0')
# (1543602919796, 16, 'paid', None, None, 1076, 'Birmingham-Hoover, AL', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.77.4 (KHTML, like Gecko) Version/7.0.5 Safari/537.77.4"')
# (1543602985796, 49, 'paid', None, None, 1114, 'San Francisco-Oakland-Hayward, CA', 'Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20100101 Firefox/31.0')
# (1543603162796, 49, 'paid', None, None, 1114, 'San Francisco-Oakland-Hayward, CA', 'Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20100101 Firefox/31.0')
# (1543603205796, 16, 'paid', None, None, 1076, 'Birmingham-Hoover, AL', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.77.4 (KHTML, like Gecko) Version/7.0.5 Safari/537.77.4"')
# (1543603476796, 16, 'paid', None, None, 1076, 'Birmingham-Hoover, AL', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.77.4 (KHTML, like Gecko) Version/7.0.5 Safari/537.77.4"')
# (1543603678796, 16, 'paid', None, None, 1076, 'Birmingham-Hoover, AL', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.77.4 (KHTML, like Gecko) Version/7.0.5 Safari/537.77.4"')
# (1543603884796, 16, 'paid', None, None, 1076, 'Birmingham-Hoover, AL', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.77.4 (KHTML, like Gecko) Version/7.0.5 Safari/537.77.4"')
# (1543607664796, 5, 'free', None, None, 985, 'Detroit-Warren-Dearborn, MI', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.77.4 (KHTML, like Gecko) Version/7.0.5 Safari/537.77.4"')

# %% [markdown]
# Run `test.ipynb` to see if you've successfully added records to this table.

# %% [markdown]
# # Close Connection to Sparkify Database

# %%
conn.close()

# %% [markdown]
# # Implement `etl.py`
# Use what you've completed in this notebook to implement `etl.py`.
